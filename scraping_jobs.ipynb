# %%
import requests
import time
from bs4 import BeautifulSoup
import re
import pymongo

base_url = 'https://in.indeed.com/jobs?q=python+developer&start='
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'
}


page = 0
count = 0
jobs_data = []
while page < 100:
    url = base_url+str(page)
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    data = soup.find_all('li', {'class': 'css-5lfssm eu4oa1w0'})
    
    for i in data:
        try:
            pos = (i.h2.a.span.string)
            a = list(i.td)
            loc = (a[1].div.div.string)
            company = (a[1].div.span.string)

            url1 = url+'&vjk='+a[0].h2.a.get('id')[4:]
            response1 = requests.get(url1, headers=headers)
            soup1 = BeautifulSoup(response1.text, 'html.parser')
            sal = soup1.body.main.div.find("div", {"id":"jobsearch-ViewjobPaneWrapper"}).div.find("div", {"class":"css-kyg8or eu4oa1w0"}).span.string
            
            pattern_range = r'₹([\d,\.]+)\s*-\s*₹([\d,\.]+)'
            pattern_single = r'₹([\d,\.]+)'

            # Extracting salary ranges  
            match_range = re.search(pattern_range, sal)
            match_single = re.search(pattern_single, sal)

            if match_range:
                min_salary = float(match_range.group(1).replace(',', ''))
                max_salary = float(match_range.group(2).replace(',', ''))
                salary = max_salary
            elif match_single:
                salary = float(match_single.group(1).replace(',', ''))
            
            
            jobs_data.append({
            "id": count,
            "title": pos,
            "company": company,
            "location": loc,
            "salary": salary
            })
            
            count += 1
            
        except:
            pass
    page += 10
    
    time.sleep(2)  # add a delay between requests to avoid being blocked by Indeed
print(count)
print(jobs_data)
# Out:
# 0
# ...

# %%
import requests
import time
from bs4 import BeautifulSoup
import re
import pymongo

base_url = 'https://in.indeed.com/jobs?q=python+developer&start='
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'
}


page = 0
count = 0
jobs_data = []
while page < 100:
    url = base_url+str(page)
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    data = soup.find_all('li', {'class': 'css-5lfssm eu4oa1w0'})
    
    for i in data:
        try:
            pos = (i.h2.a.span.string)
            a = list(i.td)
            loc = (a[1].div.div.string)
            company = (a[1].div.span.string)

            url1 = url+'&vjk='+a[0].h2.a.get('id')[4:]
            response1 = requests.get(url1, headers=headers)
            soup1 = BeautifulSoup(response1.text, 'html.parser')
            sal = soup1.body.main.div.find("div", {"id":"jobsearch-ViewjobPaneWrapper"}).div.find("div", {"class":"css-kyg8or eu4oa1w0"}).span.string
            
            pattern_range = r'₹([\d,\.]+)\s*-\s*₹([\d,\.]+)'
            pattern_single = r'₹([\d,\.]+)'

            # Extracting salary ranges  
            match_range = re.search(pattern_range, sal)
            match_single = re.search(pattern_single, sal)

            if match_range:
                min_salary = float(match_range.group(1).replace(',', ''))
                max_salary = float(match_range.group(2).replace(',', ''))
                salary = max_salary
            elif match_single:
                salary = float(match_single.group(1).replace(',', ''))
            
            
            jobs_data.append({
            "id": count,
            "title": pos,
            "company": company,
            "location": loc,
            "salary": salary
            })
            
            count += 1
            
        except:
            pass
    page += 10
    
    time.sleep(2)  # add a delay between requests to avoid being blocked by Indeed
print(count)
print(jobs_data)

# Connect to MongoDB Atlas
client = pymongo.MongoClient("mongodb+srv://harshjaiswal40383:#Scrap1234@job-db.b5des2q.mongodb.net/?retryWrites=true&w=majority&appName=job-db")
db = client["job-db"]
collection = db["jobs_job"]

# Insert the documents into the collection
try:
    result = collection.insert_many(obj)
    print("Documents inserted successfully. Inserted IDs:", result.inserted_ids)
except pymongo.errors.BulkWriteError as e:
    print("Bulk write error occurred:", e.details)

client.close()
